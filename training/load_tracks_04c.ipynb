# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# from in2stellar import Tracks, DenseNetworkGrid, set_seed
from interstellar import Tracks, DenseNetworkGrid, set_seed
# %matplotlib inline

# %% [markdown]
# Load tracks with new MLT 2.5 grid

# %%
path = '/rds/projects/d/daviesgr-cartography/mesa_grid/grid2_zams_agb/simple_grid_alex/'

# %%
tracks = Tracks(name='tracks_04c')

# %%
tracks.add_metadata(path)
tracks.get_metadata()
# Out:
#                                                file_path     m     Y   FeH  \
# 0      /rds/projects/d/daviesgr-cartography/mesa_grid...  1.00  0.24 -0.10
# 1      /rds/projects/d/daviesgr-cartography/mesa_grid...  0.94  0.32  0.00
# 2      /rds/projects/d/daviesgr-cartography/mesa_grid...  0.92  0.28 -0.30
# 3      /rds/projects/d/daviesgr-cartography/mesa_grid...  0.91  0.32  0.00
# 4      /rds/projects/d/daviesgr-cartography/mesa_grid...  1.01  0.30 -0.10
# ...                                                  ...   ...   ...   ...
# 16079  /rds/projects/d/daviesgr-cartography/mesa_grid...  0.84  0.28 -0.40
# 16080  /rds/projects/d/daviesgr-cartography/mesa_grid...  1.13  0.26  0.10
# 16081  /rds/projects/d/daviesgr-cartography/mesa_grid...  0.85  0.26  0.25
# 16082  /rds/projects/d/daviesgr-cartography/mesa_grid...  1.10  0.28 -0.40
# 16083  /rds/projects/d/daviesgr-cartography/mesa_grid...  1.12  0.32  0.10
#
#        MLT   ov  dif
# 0      2.3  0.0    1
# 1      2.5  0.0    1
# 2      1.7  0.0    1
# 3      2.5  0.0    1
# 4      2.5  0.0    1
# ...    ...  ...  ...
# 16079  1.7  0.0    1
# 16080  2.1  0.0    1
# 16081  1.5  0.0    1
# 16082  1.7  0.0    1
# 16083  1.9  0.0    1
#
# [16084 rows x 7 columns]

# %%
from interstellar.tracks import DATA_COLS

print(DATA_COLS)
# Out:
# ['initial_mass', 'initial_Yinit', 'initial_feh', 'initial_MLT', 'evol_stage', 'star_mass', 'star_age', 'frac_age', 'effective_T', 'log_g', 'luminosity', 'radius', 'star_feh', 'delta_nu_fit']

# %%
cols = DATA_COLS + ['surface_he4', 'surface_Z']
print(cols)
# Out:
# ['initial_mass', 'initial_Yinit', 'initial_feh', 'initial_MLT', 'evol_stage', 'star_mass', 'star_age', 'frac_age', 'effective_T', 'log_g', 'luminosity', 'radius', 'star_feh', 'delta_nu_fit', 'surface_he4', 'surface_Z']

# %%
tracks.load_data(usecols=cols)
tracks._data.head()
# Out:
#    evol_stage  initial_mass  initial_Yinit  initial_feh  initial_MLT  \
# 0           0           1.0           0.24         -0.1          2.3
# 1           0           1.0           0.24         -0.1          2.3
# 2           0           1.0           0.24         -0.1          2.3
# 3           0           1.0           0.24         -0.1          2.3
# 4           0           1.0           0.24         -0.1          2.3
#
#    star_mass  star_age  frac_age  effective_T  luminosity    radius     log_g  \
# 0        1.0  0.000117  0.000013  4645.111846    9.102513  4.664952  3.100195
# 1        1.0  0.000121  0.000013  4646.796973    8.869433  4.601499  3.112091
# 2        1.0  0.000125  0.000014  4647.737730    8.690322  4.552957  3.121302
# 3        1.0  0.000128  0.000014  4648.474193    8.553160  4.515453  3.128487
# 4        1.0  0.000130  0.000014  4649.057912    8.443823  4.485372  3.134292
#
#    surface_he4  surface_Z  star_feh  delta_nu_fit
# 0     0.239966   0.010769 -0.100123     12.421090
# 1     0.239967   0.010769 -0.100117     12.685399
# 2     0.239968   0.010769 -0.100103     12.894007
# 3     0.239969   0.010770 -0.100092     13.059153
# 4     0.239969   0.010770 -0.100084     13.194113

# %%
zx_sun = 0.0181

zx = 10.0**tracks.get_data('initial_feh') * zx_sun

tracks._data['initial_Zinit'] = (1.0 - tracks.get_data('initial_Yinit')) / (1.0 + 1.0/zx)

# %% [markdown]
# Note, evo_stage incorrectly defined. Instead we choose to cut the data given a fractional age above 0.01

# %%
condition = tracks.get_data('frac_age') > 0.01
tracks.select_data(condition)
# Out:
#           evol_stage  initial_mass  initial_Yinit  initial_feh  initial_MLT  \
# 423                1          1.00           0.24         -0.1          2.3
# 424                1          1.00           0.24         -0.1          2.3
# 425                1          1.00           0.24         -0.1          2.3
# 426                1          1.00           0.24         -0.1          2.3
# 427                1          1.00           0.24         -0.1          2.3
# ...              ...           ...            ...          ...          ...
# 16570536           2          1.12           0.32          0.1          1.9
# 16570537           2          1.12           0.32          0.1          1.9
# 16570538           2          1.12           0.32          0.1          1.9
# 16570539           2          1.12           0.32          0.1          1.9
# 16570540           2          1.12           0.32          0.1          1.9
#
#           star_mass  star_age  frac_age  effective_T  luminosity    radius  \
# 423        1.000000  0.101718  0.011245  5761.769950    0.750791  0.870776
# 424        1.000000  0.115514  0.012770  5762.374620    0.752437  0.871547
# 425        1.000000  0.132069  0.014600  5762.941699    0.754108  0.872343
# 426        1.000000  0.151936  0.016796  5763.497113    0.755837  0.873174
# 427        1.000000  0.175776  0.019431  5764.093057    0.757678  0.874056
# ...             ...       ...       ...          ...         ...       ...
# 16570536   1.117182  5.160961  1.300383  5016.261144    4.292697  2.747032
# 16570537   1.117176  5.162723  1.300827  5014.258156    4.313443  2.755862
# 16570538   1.117170  5.164464  1.301265  5012.440330    4.333759  2.764348
# 16570539   1.117164  5.166181  1.301698  5010.615529    4.354397  2.772941
# 16570540   1.117158  5.167883  1.302127  5008.864124    4.374703  2.781343
#
#              log_g  surface_he4  surface_Z  star_feh  delta_nu_fit  \
# 423       4.558076     0.239467   0.010753 -0.101076    166.231104
# 424       4.557307     0.239379   0.010749 -0.101265    166.011292
# 425       4.556515     0.239273   0.010745 -0.101491    165.785809
# 426       4.555688     0.239144   0.010740 -0.101767    165.551124
# 427       4.554811     0.238991   0.010735 -0.102098    165.302955
# ...            ...          ...        ...       ...           ...
# 16570536  3.608286     0.315549   0.014960  0.092133     31.403249
# 16570537  3.605496     0.315549   0.014960  0.092133     31.249675
# 16570538  3.602823     0.315685   0.014962  0.092283     31.096966
# 16570539  3.600125     0.315755   0.014963  0.092359     30.952028
# 16570540  3.597495     0.315899   0.014965  0.092514     30.808435
#
#           initial_Zinit
# 423            0.010772
# 424            0.010772
# 425            0.010772
# 426            0.010772
# 427            0.010772
# ...                 ...
# 16570536       0.015150
# 16570537       0.015150
# 16570538       0.015150
# 16570539       0.015150
# 16570540       0.015150
#
# [9669666 rows x 17 columns]

# %%
tracks.select_data(condition, inplace=True)

# %%
x_cols = ['frac_age', 'initial_mass', 'initial_MLT', 'initial_feh', 'initial_Yinit', 'initial_Zinit']
y_cols = ['star_age', 'effective_T', 'radius', 'delta_nu_fit', 'star_feh', 'surface_he4', 'surface_Z']

# %% [markdown]
# ## Preprocessing
#
# ### Gradient
#
# We will not be using all the data in training, because we want to have preference to data where there is high change it observables. A simple way to do this is to calculate the gradient in logg and teff for each track. We may then use this as the weights when randomly sampling the full set of tracks. For this to be effective, we need to sample a smaller number of models then the total, effectively dropping points where the gradient is low since these will be more easily learnt by the neural network.

# %%
def gradient(track, logg_sun=4.44, teff_sun=5777.0):
    return ((np.gradient(track['effective_T'] / teff_sun))**2.0 + \
                  (np.gradient(track['log_g'] / logg_sun))**2.0)**0.5

# %%
def frac_evol(track):
    return 1.0 + (track['star_age'] - track['star_age'].min()) / \
           (track['star_age'].max() - track['star_age'].min())

# %%
tracks._data.loc[tracks._data.frac_age<=1.0, 'frac_evol'] = tracks._data.loc[tracks._data.frac_age<=1.0, 'frac_age']

# %%
grouped = tracks._data.groupby(by=['initial_mass', 'initial_MLT', 'initial_feh', 'initial_Yinit'])
cond = tracks._data.frac_age>1.0
for name, group in grouped:
    tracks._data.loc[group.index, 'gradient'] = gradient(group)
    cond = group.frac_age>1.0
    tracks._data.loc[group[cond].index, 'frac_evol'] = frac_evol(group.loc[cond])

# %%
ax = tracks._data.sample(50000).plot(kind='scatter', x='effective_T', y='log_g',
                              c='frac_evol', cmap='viridis', s=1, figsize=(12, 12), alpha=0.5)
ax.invert_xaxis()
ax.invert_yaxis();

# %%
tracks._data.plot(kind='hist', y='frac_evol')

# %%
tracks._data.head()
# Out:
#      evol_stage  initial_mass  initial_Yinit  initial_feh  initial_MLT  \
# 423           1           1.0           0.24         -0.1          2.3
# 424           1           1.0           0.24         -0.1          2.3
# 425           1           1.0           0.24         -0.1          2.3
# 426           1           1.0           0.24         -0.1          2.3
# 427           1           1.0           0.24         -0.1          2.3
#
#      star_mass  star_age  frac_age  effective_T  luminosity    radius  \
# 423        1.0  0.101718  0.011245  5761.769950    0.750791  0.870776
# 424        1.0  0.115514  0.012770  5762.374620    0.752437  0.871547
# 425        1.0  0.132069  0.014600  5762.941699    0.754108  0.872343
# 426        1.0  0.151936  0.016796  5763.497113    0.755837  0.873174
# 427        1.0  0.175776  0.019431  5764.093057    0.757678  0.874056
#
#         log_g  surface_he4  surface_Z  star_feh  delta_nu_fit  initial_Zinit  \
# 423  4.558076     0.239467   0.010753 -0.101076    166.231104       0.010772
# 424  4.557307     0.239379   0.010749 -0.101265    166.011292       0.010772
# 425  4.556515     0.239273   0.010745 -0.101491    165.785809       0.010772
# 426  4.555688     0.239144   0.010740 -0.101767    165.551124       0.010772
# 427  4.554811     0.238991   0.010735 -0.102098    165.302955       0.010772
#
#      frac_evol  gradient
# 423   0.011245  0.000202
# 424   0.012770  0.000203
# 425   0.014600  0.000207
# 426   0.016796  0.000216
# 427   0.019431  0.000233

# %% [markdown]
# Below we can see many points have a small gradient.

# %%
fig, ax = plt.subplots(figsize=(8, 6))
tracks._data.sample(n=10000).plot(kind='hist', ax=ax, y='gradient', bins=20)

# %%
fig, ax = plt.subplots(figsize=(8, 6))
tracks._data.sample(n=10000, weights='gradient').plot(kind='hist', ax=ax, y='gradient', bins=20)

# %%
print('Length = ', len(tracks._data))
# Out:
# Length =  9669666

# %%
tracks._data.head()
# Out:
#      evol_stage  initial_mass  initial_Yinit  initial_feh  initial_MLT  \
# 423           1           1.0           0.24         -0.1          2.3
# 424           1           1.0           0.24         -0.1          2.3
# 425           1           1.0           0.24         -0.1          2.3
# 426           1           1.0           0.24         -0.1          2.3
# 427           1           1.0           0.24         -0.1          2.3
#
#      star_mass  star_age  frac_age  effective_T  luminosity    radius  \
# 423        1.0  0.101718  0.011245  5761.769950    0.750791  0.870776
# 424        1.0  0.115514  0.012770  5762.374620    0.752437  0.871547
# 425        1.0  0.132069  0.014600  5762.941699    0.754108  0.872343
# 426        1.0  0.151936  0.016796  5763.497113    0.755837  0.873174
# 427        1.0  0.175776  0.019431  5764.093057    0.757678  0.874056
#
#         log_g  surface_he4  surface_Z  star_feh  delta_nu_fit  initial_Zinit  \
# 423  4.558076     0.239467   0.010753 -0.101076    166.231104       0.010772
# 424  4.557307     0.239379   0.010749 -0.101265    166.011292       0.010772
# 425  4.556515     0.239273   0.010745 -0.101491    165.785809       0.010772
# 426  4.555688     0.239144   0.010740 -0.101767    165.551124       0.010772
# 427  4.554811     0.238991   0.010735 -0.102098    165.302955       0.010772
#
#      frac_evol  gradient
# 423   0.011245  0.000202
# 424   0.012770  0.000203
# 425   0.014600  0.000207
# 426   0.016796  0.000216
# 427   0.019431  0.000233

# %%
tracks._data.drop(columns='star_mass', inplace=True)  # Drop star mass as not needed here

# %% [markdown]
# Reduce size by converting to 32-bit float.

# %%
float_cols = tracks._data.select_dtypes(float).columns

tracks._data[float_cols] = tracks._data.loc[:, float_cols].astype(np.float32)

# %%
tracks._data['initial_mass']
# Out:
# 423         1.00
# 424         1.00
# 425         1.00
# 426         1.00
# 427         1.00
#             ...
# 16570536    1.12
# 16570537    1.12
# 16570538    1.12
# 16570539    1.12
# 16570540    1.12
# Name: initial_mass, Length: 9669666, dtype: float32

# %%
save_path = f'/rds/projects/d/daviesgr-alex-phd/interstellar_data/{tracks.name}'

tracks.save(save_path)
