# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from in2stellar import Tracks, DenseNetworkGrid, set_seed
from interstellar import Tracks, DenseNetworkGrid, set_seed
# %matplotlib inline

# %%
data_path = '/rds/projects/d/daviesgr-cartography/mesa_grid/grid2_zams_agb/simple_grid_alex_ff'

# %%
tracks = Tracks(data_path)

# %%
tracks.compile_metadata()
tracks.get_metadata()
# Out:
#                                   file_name     m     Y  FeH  MLT   ov  dif
# 0       m1.0Y0.24FeH-0.1MLT2.3ov0.0dif1.csv  1.00  0.24 -0.1  2.3  0.0    1
# 1      m0.92Y0.28FeH-0.3MLT1.7ov0.0dif1.csv  0.92  0.28 -0.3  1.7  0.0    1
# 2       m0.82Y0.32FeH0.1MLT2.1ov0.0dif1.csv  0.82  0.32  0.1  2.1  0.0    1
# 3       m0.82Y0.24FeH0.0MLT1.9ov0.0dif1.csv  0.82  0.24  0.0  1.9  0.0    1
# 4       m1.17Y0.28FeH0.1MLT2.3ov0.0dif1.csv  1.17  0.28  0.1  2.3  0.0    1
# ...                                     ...   ...   ...  ...  ...  ...  ...
# 10691  m0.84Y0.32FeH-0.1MLT2.3ov0.0dif1.csv  0.84  0.32 -0.1  2.3  0.0    1
# 10692  m0.84Y0.28FeH-0.4MLT1.7ov0.0dif1.csv  0.84  0.28 -0.4  1.7  0.0    1
# 10693   m1.13Y0.26FeH0.1MLT2.1ov0.0dif1.csv  1.13  0.26  0.1  2.1  0.0    1
# 10694   m1.1Y0.28FeH-0.4MLT1.7ov0.0dif1.csv  1.10  0.28 -0.4  1.7  0.0    1
# 10695   m1.12Y0.32FeH0.1MLT1.9ov0.0dif1.csv  1.12  0.32  0.1  1.9  0.0    1
#
# [10696 rows x 7 columns]

# %%
from interstellar.tracks import DATA_COLS

print(DATA_COLS)
# Out:
# ['initial_mass', 'initial_Yinit', 'initial_feh', 'initial_MLT', 'evol_stage', 'star_mass', 'star_age', 'frac_age', 'effective_T', 'log_g', 'luminosity', 'radius', 'star_feh', 'delta_nu_fit']

# %%
cols = DATA_COLS + ['initial_Z', 'surface_he4', 'surface_Z', 'he_core_mass']
print(cols)
# Out:
# ['initial_mass', 'initial_Yinit', 'initial_feh', 'initial_MLT', 'evol_stage', 'star_mass', 'star_age', 'frac_age', 'effective_T', 'log_g', 'luminosity', 'radius', 'star_feh', 'delta_nu_fit', 'initial_Z', 'surface_he4', 'surface_Z', 'he_core_mass']

# %%
tracks.compile_data(usecols=cols)
tracks.get_data()
# Out:
#           evol_stage  initial_mass  initial_Yinit  initial_feh  initial_MLT  \
# 0                  0          1.00           0.24         -0.1          2.3
# 1                  0          1.00           0.24         -0.1          2.3
# 2                  0          1.00           0.24         -0.1          2.3
# 3                  0          1.00           0.24         -0.1          2.3
# 4                  0          1.00           0.24         -0.1          2.3
# ...              ...           ...            ...          ...          ...
# 10966927           2          1.12           0.32          0.1          1.9
# 10966928           2          1.12           0.32          0.1          1.9
# 10966929           2          1.12           0.32          0.1          1.9
# 10966930           2          1.12           0.32          0.1          1.9
# 10966931           2          1.12           0.32          0.1          1.9
#
#           initial_Z  star_mass  star_age  frac_age  effective_T  luminosity  \
# 0          0.010769   1.000000  0.000117  0.000013  4645.111846    9.102513
# 1          0.010769   1.000000  0.000121  0.000013  4646.796973    8.869433
# 2          0.010769   1.000000  0.000125  0.000014  4647.737730    8.690322
# 3          0.010769   1.000000  0.000128  0.000014  4648.474193    8.553160
# 4          0.010769   1.000000  0.000130  0.000014  4649.057912    8.443823
# ...             ...        ...       ...       ...          ...         ...
# 10966927   0.015145   1.117182  5.160961  1.300383  5016.261144    4.292697
# 10966928   0.015145   1.117176  5.162723  1.300827  5014.258156    4.313443
# 10966929   0.015145   1.117170  5.164464  1.301265  5012.440330    4.333759
# 10966930   0.015145   1.117164  5.166181  1.301698  5010.615529    4.354397
# 10966931   0.015145   1.117158  5.167883  1.302127  5008.864124    4.374703
#
#             radius     log_g  surface_he4  surface_Z  star_feh  he_core_mass  \
# 0         4.664952  3.100195     0.239966   0.010769 -0.100123      0.000000
# 1         4.601499  3.112091     0.239967   0.010769 -0.100117      0.000000
# 2         4.552957  3.121302     0.239968   0.010769 -0.100103      0.000000
# 3         4.515453  3.128487     0.239969   0.010770 -0.100092      0.000000
# 4         4.485372  3.134292     0.239969   0.010770 -0.100084      0.000000
# ...            ...       ...          ...        ...       ...           ...
# 10966927  2.747032  3.608286     0.315549   0.014960  0.092133      0.155292
# 10966928  2.755862  3.605496     0.315549   0.014960  0.092133      0.155564
# 10966929  2.764348  3.602823     0.315685   0.014962  0.092283      0.155805
# 10966930  2.772941  3.600125     0.315755   0.014963  0.092359      0.156066
# 10966931  2.781343  3.597495     0.315899   0.014965  0.092514      0.156276
#
#           delta_nu_fit
# 0            12.421090
# 1            12.685399
# 2            12.894007
# 3            13.059153
# 4            13.194113
# ...                ...
# 10966927     31.403249
# 10966928     31.249675
# 10966929     31.096966
# 10966930     30.952028
# 10966931     30.808435
#
# [10966932 rows x 18 columns]

# %% [markdown]
# Note, evo_stage incorrectly defined. Instead we choose to cut the data given a fractional age above 0.01

# %%
condition = tracks.get_data('frac_age') > 0.01
tracks.select_data(condition)
# Out:
#           evol_stage  initial_mass  initial_Yinit  initial_feh  initial_MLT  \
# 423                1          1.00           0.24         -0.1          2.3
# 424                1          1.00           0.24         -0.1          2.3
# 425                1          1.00           0.24         -0.1          2.3
# 426                1          1.00           0.24         -0.1          2.3
# 427                1          1.00           0.24         -0.1          2.3
# ...              ...           ...            ...          ...          ...
# 10966927           2          1.12           0.32          0.1          1.9
# 10966928           2          1.12           0.32          0.1          1.9
# 10966929           2          1.12           0.32          0.1          1.9
# 10966930           2          1.12           0.32          0.1          1.9
# 10966931           2          1.12           0.32          0.1          1.9
#
#           initial_Z  star_mass  star_age  frac_age  effective_T  luminosity  \
# 423        0.010769   1.000000  0.101718  0.011245  5761.769950    0.750791
# 424        0.010769   1.000000  0.115514  0.012770  5762.374620    0.752437
# 425        0.010769   1.000000  0.132069  0.014600  5762.941699    0.754108
# 426        0.010769   1.000000  0.151936  0.016796  5763.497113    0.755837
# 427        0.010769   1.000000  0.175776  0.019431  5764.093057    0.757678
# ...             ...        ...       ...       ...          ...         ...
# 10966927   0.015145   1.117182  5.160961  1.300383  5016.261144    4.292697
# 10966928   0.015145   1.117176  5.162723  1.300827  5014.258156    4.313443
# 10966929   0.015145   1.117170  5.164464  1.301265  5012.440330    4.333759
# 10966930   0.015145   1.117164  5.166181  1.301698  5010.615529    4.354397
# 10966931   0.015145   1.117158  5.167883  1.302127  5008.864124    4.374703
#
#             radius     log_g  surface_he4  surface_Z  star_feh  he_core_mass  \
# 423       0.870776  4.558076     0.239467   0.010753 -0.101076      0.000000
# 424       0.871547  4.557307     0.239379   0.010749 -0.101265      0.000000
# 425       0.872343  4.556515     0.239273   0.010745 -0.101491      0.000000
# 426       0.873174  4.555688     0.239144   0.010740 -0.101767      0.000000
# 427       0.874056  4.554811     0.238991   0.010735 -0.102098      0.000000
# ...            ...       ...          ...        ...       ...           ...
# 10966927  2.747032  3.608286     0.315549   0.014960  0.092133      0.155292
# 10966928  2.755862  3.605496     0.315549   0.014960  0.092133      0.155564
# 10966929  2.764348  3.602823     0.315685   0.014962  0.092283      0.155805
# 10966930  2.772941  3.600125     0.315755   0.014963  0.092359      0.156066
# 10966931  2.781343  3.597495     0.315899   0.014965  0.092514      0.156276
#
#           delta_nu_fit
# 423         166.231104
# 424         166.011292
# 425         165.785809
# 426         165.551124
# 427         165.302955
# ...                ...
# 10966927     31.403249
# 10966928     31.249675
# 10966929     31.096966
# 10966930     30.952028
# 10966931     30.808435
#
# [6354056 rows x 18 columns]

# %%
tracks.select_data(condition, inplace=True)

# %%
tracks._data['frac_he_core_mass'] = tracks.get_data('he_core_mass')/tracks.get_data('initial_mass')
tracks.get_data().head()
# Out:
#      evol_stage  initial_mass  initial_Yinit  initial_feh  initial_MLT  \
# 423           1           1.0           0.24         -0.1          2.3
# 424           1           1.0           0.24         -0.1          2.3
# 425           1           1.0           0.24         -0.1          2.3
# 426           1           1.0           0.24         -0.1          2.3
# 427           1           1.0           0.24         -0.1          2.3
#
#      initial_Z  star_mass  star_age  frac_age  effective_T  luminosity  \
# 423   0.010769        1.0  0.101718  0.011245  5761.769950    0.750791
# 424   0.010769        1.0  0.115514  0.012770  5762.374620    0.752437
# 425   0.010769        1.0  0.132069  0.014600  5762.941699    0.754108
# 426   0.010769        1.0  0.151936  0.016796  5763.497113    0.755837
# 427   0.010769        1.0  0.175776  0.019431  5764.093057    0.757678
#
#        radius     log_g  surface_he4  surface_Z  star_feh  he_core_mass  \
# 423  0.870776  4.558076     0.239467   0.010753 -0.101076           0.0
# 424  0.871547  4.557307     0.239379   0.010749 -0.101265           0.0
# 425  0.872343  4.556515     0.239273   0.010745 -0.101491           0.0
# 426  0.873174  4.555688     0.239144   0.010740 -0.101767           0.0
# 427  0.874056  4.554811     0.238991   0.010735 -0.102098           0.0
#
#      delta_nu_fit  frac_he_core_mass
# 423    166.231104                0.0
# 424    166.011292                0.0
# 425    165.785809                0.0
# 426    165.551124                0.0
# 427    165.302955                0.0

# %%
x_cols = ['frac_age', 'initial_mass', 'initial_MLT', 'initial_feh', 'initial_Yinit', 'initial_Z', 'frac_he_core_mass']
y_cols = ['star_age', 'effective_T', 'radius', 'delta_nu_fit', 'star_feh', 'surface_he4', 'surface_Z']

# %%
non_log = ['star_feh', 'initial_feh', 'frac_he_core_mass']
log_cols = [col for col in x_cols+y_cols if not any([col == n for n in non_log])]
log_cols
# Out:
# ['frac_age',
#  'initial_mass',
#  'initial_MLT',
#  'initial_Yinit',
#  'initial_Z',
#  'star_age',
#  'effective_T',
#  'radius',
#  'delta_nu_fit',
#  'surface_he4',
#  'surface_Z']

# %%
tracks.log10(columns=log_cols, inplace=True)
tracks.get_data()
# Out:
#           evol_stage  initial_mass  initial_Yinit  initial_feh  initial_MLT  \
# 423                1          1.00           0.24         -0.1          2.3
# 424                1          1.00           0.24         -0.1          2.3
# 425                1          1.00           0.24         -0.1          2.3
# 426                1          1.00           0.24         -0.1          2.3
# 427                1          1.00           0.24         -0.1          2.3
# ...              ...           ...            ...          ...          ...
# 10966927           2          1.12           0.32          0.1          1.9
# 10966928           2          1.12           0.32          0.1          1.9
# 10966929           2          1.12           0.32          0.1          1.9
# 10966930           2          1.12           0.32          0.1          1.9
# 10966931           2          1.12           0.32          0.1          1.9
#
#           initial_Z  star_mass  star_age  frac_age  effective_T  ...  \
# 423        0.010769   1.000000  0.101718  0.011245  5761.769950  ...
# 424        0.010769   1.000000  0.115514  0.012770  5762.374620  ...
# 425        0.010769   1.000000  0.132069  0.014600  5762.941699  ...
# 426        0.010769   1.000000  0.151936  0.016796  5763.497113  ...
# 427        0.010769   1.000000  0.175776  0.019431  5764.093057  ...
# ...             ...        ...       ...       ...          ...  ...
# 10966927   0.015145   1.117182  5.160961  1.300383  5016.261144  ...
# 10966928   0.015145   1.117176  5.162723  1.300827  5014.258156  ...
# 10966929   0.015145   1.117170  5.164464  1.301265  5012.440330  ...
# 10966930   0.015145   1.117164  5.166181  1.301698  5010.615529  ...
# 10966931   0.015145   1.117158  5.167883  1.302127  5008.864124  ...
#
#           log_initial_mass  log_initial_MLT  log_initial_Yinit  log_initial_Z  \
# 423               0.000000         0.361728          -0.619789      -1.967825
# 424               0.000000         0.361728          -0.619789      -1.967825
# 425               0.000000         0.361728          -0.619789      -1.967825
# 426               0.000000         0.361728          -0.619789      -1.967825
# 427               0.000000         0.361728          -0.619789      -1.967825
# ...                    ...              ...                ...            ...
# 10966927          0.049218         0.278754          -0.494850      -1.819724
# 10966928          0.049218         0.278754          -0.494850      -1.819724
# 10966929          0.049218         0.278754          -0.494850      -1.819724
# 10966930          0.049218         0.278754          -0.494850      -1.819724
# 10966931          0.049218         0.278754          -0.494850      -1.819724
#
#           log_star_age  log_effective_T  log_radius  log_delta_nu_fit  \
# 423          -0.992604         3.760556   -0.060094          2.220712
# 424          -0.937366         3.760601   -0.059709          2.220138
# 425          -0.879198         3.760644   -0.059313          2.219547
# 426          -0.818340         3.760686   -0.058899          2.218932
# 427          -0.755041         3.760731   -0.058461          2.218281
# ...                ...              ...         ...               ...
# 10966927      0.712731         3.700380    0.438864          1.496975
# 10966928      0.712879         3.700207    0.440257          1.494846
# 10966929      0.713025         3.700049    0.441593          1.492718
# 10966930      0.713170         3.699891    0.442941          1.490689
# 10966931      0.713313         3.699739    0.444255          1.488670
#
#           log_surface_he4  log_surface_Z
# 423             -0.620754      -1.968479
# 424             -0.620914      -1.968614
# 425             -0.621106      -1.968777
# 426             -0.621340      -1.968976
# 427             -0.621619      -1.969213
# ...                   ...            ...
# 10966927        -0.500934      -1.825065
# 10966928        -0.500934      -1.825065
# 10966929        -0.500746      -1.825006
# 10966930        -0.500650      -1.824976
# 10966931        -0.500452      -1.824917
#
# [6354056 rows x 30 columns]

# %%
x_cols = [f'log_{col}' if not any([col == n for n in non_log]) else col for col in x_cols ]
y_cols = [f'log_{col}' if not any([col == n for n in non_log]) else col for col in y_cols ]
print(x_cols)
print(y_cols)
# Out:
# ['log_frac_age', 'log_initial_mass', 'log_initial_MLT', 'initial_feh', 'log_initial_Yinit', 'log_initial_Z', 'frac_he_core_mass']
# ['log_star_age', 'log_effective_T', 'log_radius', 'log_delta_nu_fit', 'star_feh', 'log_surface_he4', 'log_surface_Z']

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(16, 9))
tracks.sample_data(number=10000).plot(kind='hist', ax=ax,
                       y=x_cols+y_cols,
                       bins=40, alpha=0.5)

# %%
fac, df = tracks.normalize(loc='50%', columns=x_cols+y_cols)
fac
# Out:
#                column             norm_column       loc  scale
# 0        log_frac_age       log_frac_age_norm -0.069102    1.0
# 1    log_initial_mass   log_initial_mass_norm  0.000000    1.0
# 2     log_initial_MLT    log_initial_MLT_norm  0.278754    1.0
# 3         initial_feh        initial_feh_norm  0.000000    1.0
# 4   log_initial_Yinit  log_initial_Yinit_norm -0.552842    1.0
# 5       log_initial_Z      log_initial_Z_norm -1.892959    1.0
# 6   frac_he_core_mass  frac_he_core_mass_norm  0.000000    1.0
# 7        log_star_age       log_star_age_norm  0.741631    1.0
# 8     log_effective_T    log_effective_T_norm  3.752971    1.0
# 9          log_radius         log_radius_norm  0.095044    1.0
# 10   log_delta_nu_fit   log_delta_nu_fit_norm  1.990901    1.0
# 11           star_feh           star_feh_norm -0.095331    1.0
# 12    log_surface_he4    log_surface_he4_norm -0.623555    1.0
# 13      log_surface_Z      log_surface_Z_norm -1.956042    1.0

# %%
df.head()
# Out:
#      log_frac_age_norm  log_initial_mass_norm  log_initial_MLT_norm  \
# 423          -1.879955                    0.0              0.082974
# 424          -1.824717                    0.0              0.082974
# 425          -1.766549                    0.0              0.082974
# 426          -1.705691                    0.0              0.082974
# 427          -1.642392                    0.0              0.082974
#
#      initial_feh_norm  log_initial_Yinit_norm  log_initial_Z_norm  \
# 423              -0.1               -0.066947           -0.074866
# 424              -0.1               -0.066947           -0.074866
# 425              -0.1               -0.066947           -0.074866
# 426              -0.1               -0.066947           -0.074866
# 427              -0.1               -0.066947           -0.074866
#
#      frac_he_core_mass_norm  log_star_age_norm  log_effective_T_norm  \
# 423                     0.0          -1.734235              0.007585
# 424                     0.0          -1.678997              0.007630
# 425                     0.0          -1.620829              0.007673
# 426                     0.0          -1.559971              0.007715
# 427                     0.0          -1.496672              0.007760
#
#      log_radius_norm  log_delta_nu_fit_norm  star_feh_norm  \
# 423        -0.155138               0.229812      -0.005746
# 424        -0.154753               0.229237      -0.005934
# 425        -0.154357               0.228647      -0.006160
# 426        -0.153944               0.228031      -0.006436
# 427        -0.153505               0.227380      -0.006767
#
#      log_surface_he4_norm  log_surface_Z_norm
# 423              0.002801           -0.012437
# 424              0.002641           -0.012573
# 425              0.002450           -0.012735
# 426              0.002215           -0.012934
# 427              0.001936           -0.013172

# %% [markdown]
# Let's simplfy the normalization factors by rounding them to 3 decimal places.

# %%
precision = 3
loc = round(fac['loc'], 3).to_list()
loc
# Out:
# [-0.069,
#  0.0,
#  0.279,
#  0.0,
#  -0.553,
#  -1.893,
#  0.0,
#  0.742,
#  3.753,
#  0.095,
#  1.991,
#  -0.095,
#  -0.624,
#  -1.956]

# %%
fac, df = tracks.normalize(loc=loc, columns=x_cols+y_cols)
fac
# Out:
#                column             norm_column    loc  scale
# 0        log_frac_age       log_frac_age_norm -0.069    1.0
# 1    log_initial_mass   log_initial_mass_norm  0.000    1.0
# 2     log_initial_MLT    log_initial_MLT_norm  0.279    1.0
# 3         initial_feh        initial_feh_norm  0.000    1.0
# 4   log_initial_Yinit  log_initial_Yinit_norm -0.553    1.0
# 5       log_initial_Z      log_initial_Z_norm -1.893    1.0
# 6   frac_he_core_mass  frac_he_core_mass_norm  0.000    1.0
# 7        log_star_age       log_star_age_norm  0.742    1.0
# 8     log_effective_T    log_effective_T_norm  3.753    1.0
# 9          log_radius         log_radius_norm  0.095    1.0
# 10   log_delta_nu_fit   log_delta_nu_fit_norm  1.991    1.0
# 11           star_feh           star_feh_norm -0.095    1.0
# 12    log_surface_he4    log_surface_he4_norm -0.624    1.0
# 13      log_surface_Z      log_surface_Z_norm -1.956    1.0

# %%
df.head()
# Out:
#      log_frac_age_norm  log_initial_mass_norm  log_initial_MLT_norm  \
# 423          -1.880058                    0.0              0.082728
# 424          -1.824820                    0.0              0.082728
# 425          -1.766652                    0.0              0.082728
# 426          -1.705793                    0.0              0.082728
# 427          -1.642494                    0.0              0.082728
#
#      initial_feh_norm  log_initial_Yinit_norm  log_initial_Z_norm  \
# 423              -0.1               -0.066789           -0.074825
# 424              -0.1               -0.066789           -0.074825
# 425              -0.1               -0.066789           -0.074825
# 426              -0.1               -0.066789           -0.074825
# 427              -0.1               -0.066789           -0.074825
#
#      frac_he_core_mass_norm  log_star_age_norm  log_effective_T_norm  \
# 423                     0.0          -1.734604              0.007556
# 424                     0.0          -1.679366              0.007601
# 425                     0.0          -1.621198              0.007644
# 426                     0.0          -1.560340              0.007686
# 427                     0.0          -1.497041              0.007731
#
#      log_radius_norm  log_delta_nu_fit_norm  star_feh_norm  \
# 423        -0.155094               0.229712      -0.006076
# 424        -0.154709               0.229138      -0.006265
# 425        -0.154313               0.228547      -0.006491
# 426        -0.153899               0.227932      -0.006767
# 427        -0.153461               0.227281      -0.007098
#
#      log_surface_he4_norm  log_surface_Z_norm
# 423              0.003246           -0.012479
# 424              0.003086           -0.012614
# 425              0.002894           -0.012777
# 426              0.002660           -0.012976
# 427              0.002381           -0.013213

# %%
tracks.normalize(loc=loc, columns=x_cols+y_cols, inplace=True)
tracks.get_data().head()
# Out:
#      evol_stage  initial_mass  initial_Yinit  initial_feh  initial_MLT  \
# 423           1           1.0           0.24         -0.1          2.3
# 424           1           1.0           0.24         -0.1          2.3
# 425           1           1.0           0.24         -0.1          2.3
# 426           1           1.0           0.24         -0.1          2.3
# 427           1           1.0           0.24         -0.1          2.3
#
#      initial_Z  star_mass  star_age  frac_age  effective_T  ...  \
# 423   0.010769        1.0  0.101718  0.011245  5761.769950  ...
# 424   0.010769        1.0  0.115514  0.012770  5762.374620  ...
# 425   0.010769        1.0  0.132069  0.014600  5762.941699  ...
# 426   0.010769        1.0  0.151936  0.016796  5763.497113  ...
# 427   0.010769        1.0  0.175776  0.019431  5764.093057  ...
#
#      log_initial_Yinit_norm  log_initial_Z_norm  frac_he_core_mass_norm  \
# 423               -0.066789           -0.074825                     0.0
# 424               -0.066789           -0.074825                     0.0
# 425               -0.066789           -0.074825                     0.0
# 426               -0.066789           -0.074825                     0.0
# 427               -0.066789           -0.074825                     0.0
#
#      log_star_age_norm  log_effective_T_norm  log_radius_norm  \
# 423          -1.734604              0.007556        -0.155094
# 424          -1.679366              0.007601        -0.154709
# 425          -1.621198              0.007644        -0.154313
# 426          -1.560340              0.007686        -0.153899
# 427          -1.497041              0.007731        -0.153461
#
#      log_delta_nu_fit_norm  star_feh_norm  log_surface_he4_norm  \
# 423               0.229712      -0.006076              0.003246
# 424               0.229138      -0.006265              0.003086
# 425               0.228547      -0.006491              0.002894
# 426               0.227932      -0.006767              0.002660
# 427               0.227281      -0.007098              0.002381
#
#      log_surface_Z_norm
# 423           -0.012479
# 424           -0.012614
# 425           -0.012777
# 426           -0.012976
# 427           -0.013213
#
# [5 rows x 44 columns]

# %%
x_cols = [f'{col}_norm' for col in x_cols ]
y_cols = [f'{col}_norm' for col in y_cols ]
print(x_cols)
print(y_cols)
# Out:
# ['log_frac_age_norm', 'log_initial_mass_norm', 'log_initial_MLT_norm', 'initial_feh_norm', 'log_initial_Yinit_norm', 'log_initial_Z_norm', 'frac_he_core_mass_norm']
# ['log_star_age_norm', 'log_effective_T_norm', 'log_radius_norm', 'log_delta_nu_fit_norm', 'star_feh_norm', 'log_surface_he4_norm', 'log_surface_Z_norm']

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(16, 9))
tracks.sample_data(number=10000).plot(kind='hist', ax=ax,
                       y=x_cols+y_cols,
                       bins=40, alpha=0.5)

# %% [markdown]
# Reduce size by converting to 32-bit float.

# %%
del df

# %%
data = tracks.get_data(x_cols+y_cols).astype(np.float32)

# %% [markdown]
# Reset tracks data.

# %%
tracks.set_data(data)

# %%
save_path = '/rds/projects/d/daviesgr-alex-phd/interstellar_data/tracks_03'

tracks.save(save_path)
