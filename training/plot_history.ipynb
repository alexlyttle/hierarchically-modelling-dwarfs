# %%
from interstellar import DenseNetwork
from matplotlib import pyplot as plt

# %%
# network = DenseNetwork.from_config('/home/ADF/ajl573/Data/interstellar_data/network_10/network_10_config.json')
network = DenseNetwork.from_config('../data/networks/network_10/network_10_config.json')
network.load_model(suffix='best_model')
network.load_history()
network.model.summary()
# Out:
# Model: "network_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# inputs (InputLayer)          [(None, 5)]               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               768
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# ...

# %%
network.history.iloc[1:]
# Out:
#        epochs      loss       mae  val_loss   val_mae
# 1           1  0.346068  0.302586  0.261147  0.260502
# 2           2  0.252402  0.231872  0.203194  0.202550
# 3           3  0.176209  0.162467  0.152650  0.152005
# 4           4  0.131794  0.119649  0.105605  0.104960
# 5           5  0.100253  0.091101  0.083280  0.082635
# ...       ...       ...       ...       ...       ...
# 49995   49995  0.001989  0.001194  0.001586  0.001231
# 49996   49996  0.001975  0.001176  0.001502  0.001147
# 49997   49997  0.001959  0.001157  0.001499  0.001144
# 49998   49998  0.002005  0.001208  0.001529  0.001174
# 49999   49999  0.002042  0.001249  0.001633  0.001278
#
# [49999 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(4.2, 3.), dpi=300)

network.history.iloc[1:].plot(x='epochs', y='mae', alpha=0.5, ax=ax, label='train')
network.history.iloc[1:].plot(x='epochs', y='val_mae', alpha=0.5, ax=ax, label='validation')
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('epochs')
ax.set_ylabel('MAE')

fig.savefig('../paper/figures/loss.png', bbox_inches='tight')
