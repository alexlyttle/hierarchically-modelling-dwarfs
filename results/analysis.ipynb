# %%
import numpy as np
import pandas as pd
import seaborn as sns

from matplotlib import pyplot as plt

# %%
df = pd.read_csv('../modelling/final_models/population+sun_results/partial_pool/DR14_ASPC/population/stars/results.csv')
df.head()
# Out:
#          name  f_evol_16th  f_evol_50th  f_evol_84th  f_evol_ess_bulk  \
# 0  KIC5950854     0.787223     0.870010     0.932191      1182.432590
# 1  KIC3942719     1.796417     1.837445     1.862172      1885.696329
# 2  KIC4457351     1.741225     1.796926     1.832285      1503.245478
# 3  KIC3223000     0.237187     0.364823     0.500833      1987.754912
# 4  KIC7429287     1.412570     1.509902     1.579870      1290.288463
#
#    f_evol_ess_mean  f_evol_ess_sd  f_evol_ess_tail  f_evol_hpd_3%  \
# 0      1325.201967    1289.535691      3596.869825       0.695978
# 1      1763.440489    1762.516388      3411.294100       1.752855
# 2      1196.521278    1196.521278      1783.365241       1.681358
# 3      2009.834951    2009.834951      3181.722850       0.131731
# 4      1152.759789    1152.759789      2422.706692       1.318755
#
#    f_evol_hpd_97%  ...  mhs_ess_mean    mhs_ess_sd  mhs_ess_tail  mhs_hpd_3%  \
# ...

# %%
df.plot(x='age_mean', y='mhi_mean', 
#         xerr='age_sd', yerr='mhi_sd', 
        c='teff_mean', cmap='plasma', kind='scatter')
# Out:
# <AxesSubplot:xlabel='age_mean', ylabel='mhi_mean'>

# %%
df.plot(x='age_mean', y='mhi_mean', 
#         xerr='age_sd', yerr='mhi_sd', 
        c='mass_mean', cmap='plasma', kind='scatter')
# Out:
# <AxesSubplot:xlabel='age_mean', ylabel='mhi_mean'>

# %%
df.plot(x='mass_mean', y='mlt_mean', 
        xerr='mass_sd', yerr='mlt_sd', 
#         c='teff_mean', cmap='plasma', 
        kind='scatter')
# Out:
# <AxesSubplot:xlabel='mass_mean', ylabel='mlt_mean'>

# %%
df.plot(x='mass_mean', y='yi_mean', 
        xerr='mass_sd', yerr='yi_sd', 
#         c='teff_mean', cmap='plasma', 
        kind='scatter')
# Out:
# <AxesSubplot:xlabel='mass_mean', ylabel='yi_mean'>

# %%
df.plot(x='age_mean', y='mhi_mean', 
        xerr='age_sd', yerr='mhi_sd', 
#         c='teff_mean', cmap='plasma', 
        kind='scatter')
# Out:
# <AxesSubplot:xlabel='age_mean', ylabel='mhi_mean'>

# %%
df.plot(x='age_mean', y='yi_mean', 
        xerr='age_sd', yerr='yi_sd', 
#         c='teff_mean', cmap='plasma', 
        kind='scatter')
# Out:
# <AxesSubplot:xlabel='age_mean', ylabel='yi_mean'>

# %%
df.plot(x='teff_mean', y='mlt_mean', 
        xerr='teff_sd', yerr='mlt_sd', 
#         c='teff_mean', cmap='plasma', 
        kind='scatter')
# Out:
# <AxesSubplot:xlabel='teff_mean', ylabel='mlt_mean'>

# %%
df.plot(x='mhi_mean', y='mlt_mean', 
        xerr='mhi_sd', yerr='mlt_sd', 
#         c='teff_mean', cmap='plasma', 
        kind='scatter')
# Out:
# <AxesSubplot:xlabel='mhi_mean', ylabel='mlt_mean'>

# %%
df.plot(x='yi_mean', y='mlt_mean', 
        xerr='yi_sd', yerr='mlt_sd', 
#         c='teff_mean', cmap='plasma', 
        kind='scatter')
# Out:
# <AxesSubplot:xlabel='yi_mean', ylabel='mlt_mean'>
