# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_dr14 = pd.read_csv('../data/spectroscopy/s17_gaia_4arcsec_apogeeDR14.csv')
df_df16 = pd.read_csv('../data/spectroscopy/s17_gaia_4arcsec_apogeeDR16.csv')

df_both = pd.merge(df_dr14, df_df16, on=['KIC', 'nearest_neighbour'], suffixes=('_DR14', '_DR16'))
df = df_both.loc[df_both['nearest_neighbour']==1]
df.head()
# Out:
#                                        APSTAR_ID  \
# 0  apogee.apo25m.s.stars.4589.2M19281984+3703353
# 1  apogee.apo25m.s.stars.5021.2M19220135+3727324
# 2  apogee.apo25m.s.stars.4589.2M19313636+3737281
# 3  apogee.apo25m.s.stars.4589.2M19321765+3742592
# 4  apogee.apo25m.s.stars.4407.2M19101163+3804559
#
#                             TARGET_ID  \
# 0  4589.2M19281984+3703353
# 1  5021.2M19220135+3727324
# 2  4589.2M19313636+3737281
# 3  4589.2M19321765+3742592
# 4  4407.2M19101163+3804559
#
#                                         ASPCAP_ID  \
# 0  apogee.apo25m.s.l31c.2.4589.2M19281984+3703353
# 1  apogee.apo25m.s.l31c.2.5021.2M19220135+3727324
# 2  apogee.apo25m.s.l31c.2.4589.2M19313636+3737281
# 3  apogee.apo25m.s.l31c.2.4589.2M19321765+3742592
# 4  apogee.apo25m.s.l31c.2.4407.2M19101163+3804559
#
#                                      FILE      APOGEE_ID_DR14 TELESCOPE_DR14  \
# 0  apStar-r8-2M19281984+3703353.fits       2M19281984+3703353       apo25m
# ...

# %%
lim = [4500, 7000]

ax = df.plot(kind='scatter', x='TEFF_DR14', y='TEFF_DR16')
ax.plot(lim, lim, 'k--')
ax.set_xlim(lim)
ax.set_ylim(lim)
# Out:
# (4500, 7000)
